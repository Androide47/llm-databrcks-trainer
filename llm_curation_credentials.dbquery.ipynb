-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `llm_raw_data`
URL 's3://amzn-s2-androide-bucket/'
WITH (STORAGE CREDENTIAL `s3_databricks_access`);

GRANT CREATE EXTERNAL LOCATION ON STORAGE CREDENTIAL `s3_databricks_access` TO `andrei@lambdac.co`;

GRANT ALL PRIVILEGES ON EXTERNAL LOCATION `llm_raw_data` TO `andrei@lambdac.co`;

GRANT USE CATALOG ON CATALOG llm_curation TO `andrei@lambdac.co`;

GRANT ALL PRIVILEGES ON SCHEMA llm_curation.bronze TO `andrei@lambdac.co`;
